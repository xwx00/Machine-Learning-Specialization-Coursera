# %%
import numpy as np
import tensorflow as tf

w = tf.Variable(0, dtype=tf.float32)
optimizer = tf.keras.optimizers.Adam(0.1)

def train_step():
    with tf.GradientTape() as tape:
        cost = w ** 2 - 10 * w + 25
    trainable_variables = [w]
    grade = tape.gradient(cost, trainable_variables)
    optimizer.apply_gradients(zip(grade, trainable_variables))

print(w)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       4 w = tf.Variable(0, dtype=tf.float32)
#       5 optimizer = tf.keras.optimizers.Adam(0.1)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import pytorch as torch
w = torch.tensor(0.0, requires_grad=True)
optimizer = torch.optim.Adam([w], lr=0.1)
def train_step():
    cost = w ** 2 - 10 * w + 25
    cost.backward()
    optimizer.step()
    optimizer.zero_grad()
print(w)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pytorch as torch
#       2 w = torch.tensor(0.0, requires_grad=True)
#       3 optimizer = torch.optim.Adam([w], lr=0.1)
#
# ModuleNotFoundError: No module named 'pytorch'
